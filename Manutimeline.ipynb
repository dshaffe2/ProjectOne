# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
atl_df = pd.read_csv("C:/Users/ginaf/Atlanta.csv")
#atl_df.head()
atl_aq=pd.read_csv("C:/Users/ginaf/Annual_Averages_by_cityAtl.csv")
#atl_aq.head()

# %%
x_axis = np.arange(len(atl_df["Year"]))
tick_locations = [value+0.4 for value in x_axis]

# %%
fig, ax1 = plt.subplots(figsize=(20,6))


#color = 'tab:red'
ax1.set_xlabel("Year")
ax1.set_ylabel("Manufacturing Jobs (in thousands)")
ax1.plot(x_axis, atl_df["Annual"], color='k')
ax1.tick_params(axis='y', labelcolor='k')
ax1.set_xticks(list(range(0, len(atl_df["Year"]))))
ax1.set_xticklabels(atl_df["Year"], rotation="vertical")
ax1.axvline(6, ymin=0, ymax=1, color='g')
ax1.axvline(8, ymin=0, ymax=1, color='g')
ax1.axvline(12, ymin=0, ymax=1, color='g')
ax1.axvline(15, ymin=0, ymax=1, color='g')
ax1.axvline(25, ymin=0, ymax=1, color='g')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#color = 'tab:blue'
ax2.set_ylabel("Air Quality")  # we already handled the x-label with ax1
ax2.plot(x_axis, atl_aq["AQI"], color='b')
ax2.tick_params(axis='y', labelcolor='b')


plt.title("Manufacturing vs Air Quality: Atlanta")

plt.savefig("C:/Users/ginaf/Atlantamanuf.png")

# %%
# plt.figure(figsize=(20,3))
# plt.plot(x_axis, atl_df["Annual"], color='r', alpha=0.5)
# plt.xticks(tick_locations, atl_df["Year"], rotation="vertical")
# plt.title("Manufacturing vs Air Quality: Atlanta")
# plt.xlabel("Year")
# plt.ylabel("Manufacturing Jobs (in thousands)")
# #plt.vlines(7, 0, 8, colors='k', linestyles='solid', label='Emissions Testing')

# %%
# plt.tight_layout()
# #plt.savefig("C:/Users/ginaf/Atlantaman.png")
# plt.show()

# %%
aus_df = pd.read_csv("C:/Users/ginaf/Austin.csv")
#aus_df.head()
aus_aq=pd.read_csv("C:/Users/ginaf/Annual_Averages_by_cityAus.csv")
#aus_aq.head()

# %%
x_axis = np.arange(len(aus_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
fig, ax1 = plt.subplots(figsize=(20,6))


#color = 'tab:red'
ax1.set_xlabel("Year")
ax1.set_ylabel("Manufacturing Jobs (in thousands)")
ax1.plot(x_axis, aus_df["Annual"], color='k')
ax1.tick_params(axis='y', labelcolor='k')
ax1.set_xticks(list(range(0, len(aus_df["Year"]))))
ax1.set_xticklabels(aus_df["Year"], rotation="vertical")
ax1.axvline(1, ymin=0, ymax=1, color='g')
ax1.axvline(5, ymin=0, ymax=1, color='g')
ax1.axvline(11, ymin=0, ymax=1, color='g')
ax1.axvline(15, ymin=0, ymax=1, color='g')
ax1.axvline(19, ymin=0, ymax=1, color='g')
ax1.axvline(23, ymin=0, ymax=1, color='g')
ax1.axvline(25, ymin=0, ymax=1, color='g')


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#color = 'tab:blue'
ax2.set_ylabel("Air Quality")  # we already handled the x-label with ax1
ax2.plot(x_axis, aus_aq["AQI"], color='b')
ax2.tick_params(axis='y', labelcolor='b')


plt.title("Manufacturing vs Air Quality: Austin")

plt.savefig("C:/Users/ginaf/Austinmanuf.png")

# %%
# plt.figure(figsize=(20,3))
# plt.plot(x_axis, aus_df["Annual"], color='r', alpha=0.5)
# plt.xticks(tick_locations, aus_df["Year"], rotation="vertical")
# plt.title("Manufacturing vs Air Quality: Austin")
# plt.xlabel("Year")
# plt.ylabel("Manufacturing Jobs (in thousands)")
# #plt.vlines(1996, 0, 300, colors='k', linestyles='solid', label='Emissions Testing')

# %%
plt.tight_layout()
#plt.savefig("C:/Users/ginaf/Austinman.png")
#plt.show()

# %%
dal_df = pd.read_csv("C:/Users/ginaf/Dallas.csv")
#dal_df.head()
dal_aq=pd.read_csv("C:/Users/ginaf/Annual_Averages_by_cityDal.csv")
#dal_aq.head()

# %%
x_axis = np.arange(len(dal_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
fig, ax1 = plt.subplots(figsize=(20,6))


#color = 'tab:red'
ax1.set_xlabel("Year")
ax1.set_ylabel("Manufacturing Jobs (in thousands)")
ax1.plot(x_axis, dal_df["Annual"], color='k')
ax1.tick_params(axis='y', labelcolor='k')
ax1.set_xticks(list(range(0, len(dal_df["Year"]))))
ax1.set_xticklabels(dal_df["Year"], rotation="vertical")
ax1.axvline(1, ymin=0, ymax=1, color='g')
ax1.axvline(5, ymin=0, ymax=1, color='g')
ax1.axvline(11, ymin=0, ymax=1, color='g')
ax1.axvline(12, ymin=0, ymax=1, color='g')
ax1.axvline(19, ymin=0, ymax=1, color='g')
ax1.axvline(23, ymin=0, ymax=1, color='g')
ax1.axvline(25, ymin=0, ymax=1, color='g')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#color = 'tab:blue'
ax2.set_ylabel("Air Quality")  # we already handled the x-label with ax1
ax2.plot(x_axis, dal_aq["AQI"], color='b')
ax2.tick_params(axis='y', labelcolor='b')


plt.title("Manufacturing vs Air Quality: Dallas")

plt.savefig("C:/Users/ginaf/Dallasmanuf.png")

# %%
# plt.figure(figsize=(20,3))
# plt.plot(x_axis, dal_df["Annual"], color='r', alpha=0.5)
# plt.xticks(tick_locations, dal_df["Year"], rotation="vertical")
# plt.title("Manufacturing vs Air Quality: Dallas")
# plt.xlabel("Year")
# plt.ylabel("Manufacturing Jobs (in thousands)")
# #plt.vlines(1996, 0, 300, colors='k', linestyles='solid', label='Emissions Testing')

# %%
plt.tight_layout()
#plt.savefig("C:/Users/ginaf/Dallasman.png")
#plt.show()

# %%
nash_df = pd.read_csv("C:/Users/ginaf/Nashville.csv")
#nash_df.head()
nash_aq=pd.read_csv("C:/Users/ginaf/Annual_Averages_by_cityNash.csv")
#nash_aq.head()

# %%
x_axis = np.arange(len(nash_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
fig, ax1 = plt.subplots(figsize=(20,6))


#color = 'tab:red'
ax1.set_xlabel("Year")
ax1.set_ylabel("Manufacturing Jobs (in thousands)")
ax1.plot(x_axis, nash_df["Annual"], color='k')
ax1.tick_params(axis='y', labelcolor='k')
ax1.set_xticks(list(range(0, len(nash_df["Year"]))))
ax1.set_xticklabels(nash_df["Year"], rotation="vertical")
ax1.axvline(6, ymin=0, ymax=1, color='g')
ax1.axvline(8, ymin=0, ymax=1, color='g')
ax1.axvline(20, ymin=0, ymax=1, color='g')
ax1.axvline(25, ymin=0, ymax=1, color='g')
ax1.axvline(26, ymin=0, ymax=1, color='g')


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#color = 'tab:blue'
ax2.set_ylabel("Air Quality")  # we already handled the x-label with ax1
ax2.plot(x_axis, nash_aq["AQI"], color='b')
ax2.tick_params(axis='y', labelcolor='b')


plt.title("Manufacturing vs Air Quality: Nashville")

plt.savefig("C:/Users/ginaf/Nashvillemanuf.png")

# %%
# plt.figure(figsize=(20,3))
# plt.plot(x_axis, nash_df["Annual"], color='r', alpha=0.5)
# plt.xticks(tick_locations, nash_df["Year"], rotation="vertical")
# plt.title("Manufacturing vs Air Quality: Nashville")
# plt.xlabel("Year")
# plt.ylabel("Manufacturing Jobs (in thousands)")
# #plt.vlines(1996, 0, 300, colors='k', linestyles='solid', label='Emissions Testing')

# %%
plt.tight_layout()
#plt.savefig("C:/Users/ginaf/Dallasman.png")
#plt.show()
